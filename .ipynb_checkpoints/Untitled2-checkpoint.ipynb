# %%
demo (graphics)
# Out:
# 	demo(graphics)
# 	---- ~~~~~~~~
#
# > #  Copyright (C) 1997-2009 The R Core Team
# >
# > require(datasets)
#
# > require(grDevices); require(graphics)
#
# > ## Here is some code which illustrates some of the differences between
# > ## R and S graphics capabilities.  Note that colors are generally specified
# > ## by a character string name (taken from the X11 rgb.txt file) and that line
# > ## textures are given similarly.  The parameter "bg" sets the background
# > ## parameter for the plot and there is also an "fg" parameter which sets
# > ## the foreground color.
# >
# >
# > x <- stats::rnorm(50)
#
# > opar <- par(bg = "white")
#
# > plot(x, ann = FALSE, type = "n")
#
# > abline(h = 0, col = gray(.90))
#
# > lines(x, col = "green4", lty = "dotted")
#
# > points(x, bg = "limegreen", pch = 21)
#
# > title(main = "Simple Use of Color In a Plot",
# +       xlab = "Just a Whisper of a Label",
# +       col.main = "blue", col.lab = gray(.8),
# ...

# %%
setwd("/Users/il239838/Downloads")
cars <- read.csv(file="cars.csv",head=TRUE,sep=",")

# %%
# cars [["Weight"]] = as.integer(as.character(cars[["Weight"]]))
stripchart(cars$Weight, method="stack")
stripchart(cars$Cyl, method="stack")
# Out:
# plot without title
# plot without title

# %%
# stripchart(cars$Weight)
stripchart(cars$Cyl)
# Out:
# plot without title

# %%
hist (cars$Weight)

hist(cars$Weight, main="Distribution of cats weight",xlab="weight")
# Out:
# Plot with title “Histogram of cars$Weight”
# Plot with title “Distribution of cats weight”

# %%
hist(cars$Weight,breaks=8,xlim=c(3000,5000),col="red")
# Out:
# Plot with title “Histogram of cars$Weight”

# %%
d <- density (cars$Weight$HP) # returns the density data 
plot(d) # plots the results
# Out:
# Error in cars$Weight$HP: $ operator is invalid for atomic vectors
# Traceback:
#
# 1. density(cars$Weight$HP)

# %%
boxplot(cars$HP)
boxplot(cars$HP, horizontal = TRUE)
# Out:
# plot without title
# plot without title

# %%
boxplot(cars$Retail.Price,cars$Dealer.Cost)
# Out:
# plot without title

# %%
# plot(cars$Retail.Price,cars$Dealer.Cost)
plot (cars$HP,cars$Weight)
# cor(cars$HP,cars$Weight)
abline(lm(cars$Weight~cars$HP))
# Out:
# plot without title

# %%
cor(cars$HP,cars$Weight)
# Out:
# [1] NA

# %%
plot (cars$HP,cars$Weight,cex=0.8,pch=1, xlim = c(200,400), col = "red")
# Out:
# plot without title

# %%
plot (cars$HP,cars$Weight,cex = 1, col = ifelse(cars$Wagon == 1, "red","blue"))
legend(100, 7000, pch=c(1,1), col=c("red", "blue"), c("Wagon", "noWagon"),  box.col="darkgreen", cex=.8)
# Out:
# plot without title

# %%
cars1 = cars[,c(9,10,12,13)]
plot(cars1)
# Out:
# plot without title

# %%
headers(cars)
# Out:
# Error in eval(expr, envir, enclos): could not find function "headers"
# Traceback:
